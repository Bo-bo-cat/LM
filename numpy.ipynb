# %%
import numpy as np

# %%
from PIL import Image

# %%
matrix = np.array ([[2, 5, 2],
                   [1, 0, -2],
                   [3, 1, 1]])

# %%
matrix2 = np.array ([[-2, 1, 0],
                   [-2, 2, 1],
                   [0, 0, 3]])

# %%
np.dot (matrix, matrix2)
# Out:
# array([[-14,  12,  11],
#        [ -2,   1,  -6],
#        [ -8,   5,   4]])

# %%
 list = [2, 5, 1]

# %%
a = list * 5

# %%
print (a)
# Out:
# [2, 5, 1, 2, 5, 1, 2, 5, 1, 2, 5, 1, 2, 5, 1]

# %%
list =[2, 4, 1]

# %%
a = list + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 a = list + 3
#
# TypeError: can only concatenate list (not "int") to list

# %%
s = matrix * 2

# %%
print(s)
# Out:
# [[ 4 10  4]
#  [ 2  0 -4]
#  [ 6  2  2]]

# %%
s = matrix + 3

# %%
print(s)
# Out:
# [[5 8 5]
#  [4 3 1]
#  [6 4 4]]

# %%
b = matrix + matrix2

# %%
print(b)
# Out:
# [[ 0  6  2]
#  [-1  2 -1]
#  [ 3  1  4]]

# %%
kartezh = ("apple", "banana", "orange")

# %%
type (kartezh)
# Out:
# tuple

# %%
matrix2=(-2, 1, 0, )

# %% [raw]
# arrey=[0:2, 0:2]

# %%
image = Image.open("img_136.jpg")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
np.array(image)
# Out:
# array([[[  8,   3,   0],
#         [  0,   1,   0],
#         [  0,   1,  23],
#         ...,
#         [  4,  11,   3],
#         [ 10,   0,   0],
#         [ 14,   0,   0]],
#
#        [[ 42,   0,   0],
#         [ 28,   0,   0],
#         [ 14,  13,  19],
#         ...,
#         [  8,   0,   0],
#         [ 24,   0,   0],
#         [ 41,   0,   9]],
#
#        [[  0,  10,  34],
#         [  0,  32,  66],
#         [ 15, 165, 216],
#         ...,
#         [  0,  51,  26],
#         [  0,  19,   4],
#         [  0,  14,   4]],
#
#        ...,
#
#        [[ 14,   5,   0],
#         [  7,   0,   0],
#         [  8,   0,   0],
#         ...,
#         [  8,   0,   0],
#         [ 17,   4,   0],
#         [ 15,   2,   0]],
#
#        [[  0,   5,  12],
#         [  0,   4,  11],
#         [  0,   4,   7],
#         ...,
#         [  0,   2,   9],
#         [  0,   5,  13],
#         [  0,   3,  12]],
#
#        [[  0,   3,   4],
#         [  0,   3,   2],
#         [  0,   2,   0],
# ...
